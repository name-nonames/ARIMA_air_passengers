# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA

# %%
df_data = pd.read_csv("AirPassengers.csv")
df_data["Month"] = pd.to_datetime(df_data["Month"])
df_data.set_index("Month",inplace= True)
df_data
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# ...                 ...
# 1960-08-01          606
# 1960-09-01          508
# 1960-10-01          461
# 1960-11-01          390
# 1960-12-01          432
#
# [144 rows x 1 columns]

# %%
plt.plot(df_data)

# %%
data_test = adfuller(df_data["#Passengers"])
data_test
# Out:
# (0.815368879206063,
#  0.9918802434376413,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  996.692930839019)

# %% [markdown]
# Augmented Dickey-Fuler Test result:
# (0.815368879206063,
#  0.9918802434376413,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  996.692930839019)
#  p-value ~ 0.9919, the time series is not stationary.
#  Try to make data stationay by using:
#  log -> reduce variance
#  differencing -> remove seasomality and trend

# %%
log_data = np.log(df_data)
plt.plot(log_data)

# %%
movingavg = log_data.rolling(window =12).mean()
#movingstd = log_data.rolling(window =12).std()
log_data_I = log_data - log_data.shift()
log_data_I.dropna(inplace=True)
plt.plot(log_data_I)

# %%
log_data_I_test = adfuller(log_data_I["#Passengers"])
log_data_I_test
# Out:
# (-2.7171305983881675,
#  0.07112054815085295,
#  14,
#  128,
#  {'1%': -3.4825006939887997,
#   '5%': -2.884397984161377,
#   '10%': -2.578960197753906},
#  -440.35846985568105)

# %%
from statsmodels.tsa.stattools import acf, pacf
acf = acf(log_data_I,nlags=15)
plt.plot(acf)

# %%
pacf = pacf(log_data_I,nlags=15)
plt.plot(pacf)

# %%
from statsmodels.tsa.arima.model import ARIMA
model = ARIMA(log_data, order=(2,1,2))
result = model.fit()
# Out:
# /Users/alexiswong/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/alexiswong/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /Users/alexiswong/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
#result.summary()
plt.plot(result.fittedvalues[1:],color = "black")
plt.plot(log_data)
